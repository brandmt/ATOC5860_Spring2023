# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import scipy.stats as stats

# %%
### Read in the data
filename='homework1_data.csv'
data=pd.read_csv(filename,sep=',')
data.head()
# Out:
#     P_hPa  R_inches
# 0  842.63       0.0
# 1  842.58       0.0
# 2  842.13       0.0
# 3  842.38       0.0
# 4  842.57       0.0

# %%
P_mean = data['P_hPa'].mean()
print(f'Avg Pressure = {np.round(P_mean,2)}') 

P_avg = data[data.R_inches>=0.01]['P_hPa'].mean()
print(f'Avg Pressure when Raining = {np.round(P_avg,2)}')
# Out:
# Avg Pressure = 846.33
# Avg Pressure when Raining = 847.03

# %%
P_rain_pop = data['P_hPa']
N = len(P_rain_pop)
P_std_pop = data['P_hPa'].std()

P_rain = data[data.R_inches>=0.01]['P_hPa']
N1 = len(P_rain)
P_std = data[data.R_inches>=0.01]['P_hPa'].std()

P_norm_samp=(P_rain-P_avg)/P_std
P_norm_pop=(P_rain_pop-P_mean)/P_std_pop

## Using Barnes equation (83) to calculate probability using z-statistic
sample_mean=P_avg-P_mean
print(f'sample_mean: {np.round(sample_mean,2)}')
population_mean=0
population_std=np.std(P_rain_pop)
xstd=population_std/np.sqrt(N)
z=(sample_mean-population_mean)/xstd
print("Z-statistic:")
print(z)

## Using Barnes equation (96) to calculate probability using the t-statistic
sample_std=np.std(P_rain)
print("T-statistic:")
t=(sample_mean-population_mean)/(sample_std/(np.sqrt(N-1)))
print(np.round(t,2))
# Out:
# sample_mean: 0.7
# Z-statistic:
# 11.637323115329721
# T-statistic:
# 12.15

# %%
#### Calculate the 95% and 99% confidence limits on the 21st century warming using t-statistic
#### Assume that the global warming is normally distributed.  (See page 18 of Barnes notes)
P_rain = data['P_hPa']
P_std = data['P_hPa'].std()

N=len(P_rain)
df=N-1

# t-statistic
tstat95=stats.t.ppf(0.975,df)
low_limit95=P_mean-tstat95*(P_std/np.sqrt(N-1))
high_limit95=P_mean+tstat95*(P_std/np.sqrt(N-1))
print(f'95% confidence limits - t-statistic: {np.round(low_limit95,2)} < X < {np.round(high_limit95,2)}')

# z-statistic
zstat95=stats.norm.ppf(0.975)
low_limit95=P_mean-zstat95*(P_std/np.sqrt(N-1))
high_limit95=P_mean+zstat95*(P_std/np.sqrt(N-1))
print(f'95% confidence limits - z-statistic: {np.round(low_limit95,2)} < X < {np.round(high_limit95,2)}')
# Out:
# 95% confidence limits - t-statistic: 846.21 < X < 846.45
# 95% confidence limits - z-statistic: 846.21 < X < 846.45

# %%
plt.figure(figsize=(12,6),dpi=150)

plt.plot(data['P_hPa'])
plt.axhline(y=P_mean,color='r')
plt.xlabel('Hours')
plt.ylabel('Pressure')
plt.show()
# Out:
# 846.3322317351598

# %%
plt.figure(figsize=(12,6),dpi=150)
plt.plot(data['R_inches'])
plt.show()

# %%
plt.figure(figsize=(12,6),dpi=150)
plt.hist(data['P_hPa']-P_mean,250)
# plt.hist(data[data.R_inches>=0.01]['P_hPa'],250,color='k')
# plt.axvline(x=P_mean,color='r')
plt.axvline(x=pressure_avg-P_mean,color='g')
plt.show()
